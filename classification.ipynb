# %% [markdown]
# ## Neste desafio, você será desafiado a criar 4 modelos que possam prever se um solicitante é de baixo ou alto risco de crédito com base em informações relevantes, como histórico de crédito, valor do crédito solicitado, tempo de emprego atual, estado civil e outras variáveis. Você usará um conjunto de dados que inclui informações sobre o solicitante, bem como sua classificação de risco de crédito. Você deverá treinar e ajustar um modelo de classificação que possa prever com precisão a classe de risco de crédito de um novo solicitante com base nas informações fornecidas. Boa sorte!

# %% [markdown]
# ### Algortimos a serem usados e links dos materiais de estudo
# ### KNN - [KNN](https://membro.comunidadedatascience.com/89193-fundamentos-de-machine-learning/2150255-aula-11-k-nearest-neighbors-teoria)
#
# ### Decision Tree - [Decision Tree](https://membro.comunidadedatascience.com/89193-fundamentos-de-machine-learning/2334896-aula-41-introducao-a-decision-tree)
#
# ### Random Forest - [Random Forest](https://membro.comunidadedatascience.com/89193-fundamentos-de-machine-learning/2394374-aula-47-random-forest-teoria)
#
# ### Logistic Regression - [Logistic Regression](https://membro.comunidadedatascience.com/89193-fundamentos-de-machine-learning/2424298-aula-50-introducao-a-logistic-regression)

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from category_encoders.count import CountEncoder
from sklearn.model_selection import train_test_split

# %%
url = "datasets/train.csv"
data = pd.read_csv(url)

# %% [markdown]
# |Nome do atributo |	Descrição |
# | --- | --- |
# |checking_status|	Status da conta corrente existente |
# |duration|	Duração em meses |
# |credit_history|	Histórico de crédito do solicitante, incluindo créditos tomados, pagos devidamente, atrasos e contas críticas |
# |purpose|	Finalidade do crédito solicitado |
# |credit_amount|	Valor do crédito solicitado |
# |savings_status|	Situação da conta poupança/título do solicitante |
# |employment|	Tempo de emprego atual do solicitante, em anos |
# |installment_commitment|	Taxa de prestação em percentagem do rendimento disponível |
# |personal_status|	Estado civil e situação pessoal do solicitante |
# |other_parties|	Outras pessoas envolvidas no crédito |
# |residence_since|	Tempo de residência atual do solicitante, em anos |
# |property_magnitude|	Tamanho da propriedade possuída pelo solicitante |
# |age|	Idade do solicitante |
# |other_payment_plans|	Outros planos de pagamento em que o solicitante está inscrito |
# |housing|	Tipo de moradia do solicitante |
# |existing_credits|	Número de créditos existentes atualmente em nome do solicitante |
# |job|	Tipo de emprego atual do solicitante |
# |num_dependents|	Número de dependentes financeiros do solicitante |
# |own_telephone|	Indicação se o solicitante possui telefone próprio |
# |foreign_worker|	Indicação se o solicitante é estrangeiro |
# |class|	Classe (bom ou mau risco de crédito) atribuída ao solicitante com base em sua capacidade de pagamento |

# %%
data.shape
# Out:
# (103904, 25)

# %%
data = data.sample(50000)

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
train, test = data.
# Out:
#            id  Gender   Customer Type  Age   Type of Travel     Class  \
# 38356  116261  Female  Loyal Customer   49  Personal Travel       Eco
# 64021    8679  Female  Loyal Customer   34  Business travel  Business
# 12265   13846    Male  Loyal Customer   11  Personal Travel       Eco
# 58657    1547    Male  Loyal Customer   54  Personal Travel       Eco
# 92327   90047  Female  Loyal Customer   34  Business travel  Business
# ...       ...     ...             ...  ...              ...       ...
# 32693   15499  Female  Loyal Customer   51  Personal Travel       Eco
# 75083   62807  Female  Loyal Customer   33  Personal Travel       Eco
# 4797    33442  Female  Loyal Customer   36  Personal Travel       Eco
# 73207   33721  Female  Loyal Customer   42  Personal Travel       Eco
# 81071  107459    Male  Loyal Customer   23  Personal Travel  Eco Plus
#
#        Flight Distance  Inflight wifi service  \
# 38356              390                      3
# 64021             2169                      2
# 12265              628                      3
# 58657              862                      3
# 92327             2417                      2
# ...                ...                    ...
# 32693              377                      3
# 75083             2338                      0
# 4797              2556                      3
# 73207              667                      3
# 81071              468                      4
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 38356                                  5                       3  ...
# 64021                                  5                       5  ...
# 12265                                  5                       3  ...
# 58657                                  5                       3  ...
# 92327                                  2                       2  ...
# ...                                  ...                     ...  ...
# 32693                                  2                       3  ...
# 75083                                  1                       1  ...
# 4797                                   4                       3  ...
# 73207                                  4                       3  ...
# 81071                                  3                       4  ...
#
#        Inflight entertainment  On-board service  Leg room service  \
# 38356                       1                 1                 3
# 64021                       2                 2                 2
# 12265                       2                 3                 5
# 58657                       1                 3                 3
# 92327                       4                 4                 4
# ...                       ...               ...               ...
# 32693                       5                 5                 3
# 75083                       2                 3                 5
# 4797                        3                 2                 3
# 73207                       4                 4                 3
# 81071                       1                 3                 4
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 38356                 1                3                 1            5
# 64021                 2                2                 2            3
# 12265                 5                3                 4            2
# 58657                 5                5                 4            1
# 92327                 4                5                 4            5
# ...                 ...              ...               ...          ...
# 32693                 1                1                 5            1
# 75083                 3                4                 2            2
# 4797                  5                4                 4            4
# 73207                 4                4                 4            5
# 81071                 4                1                 3            1
#
#        Departure Delay in Minutes  Arrival Delay in Minutes  \
# 38356                           0                       0.0
# 64021                           9                       8.0
# 12265                           0                       0.0
# 58657                          10                       5.0
# 92327                           0                       0.0
# ...                           ...                       ...
# 32693                           0                       8.0
# 75083                           0                       0.0
# 4797                            2                      25.0
# 73207                           0                       3.0
# 81071                           0                      11.0
#
#                   satisfaction
# 38356  neutral or dissatisfied
# 64021  neutral or dissatisfied
# 12265  neutral or dissatisfied
# 58657  neutral or dissatisfied
# 92327                satisfied
# ...                        ...
# 32693  neutral or dissatisfied
# 75083                satisfied
# 4797   neutral or dissatisfied
# 73207  neutral or dissatisfied
# 81071  neutral or dissatisfied
#
# [50000 rows x 24 columns]

# %%
import hashlib
from datetime import datetime

def calcular_hash_md5(texto):
    md5 = hashlib.md5()
    md5.update(texto.encode('utf-8'))
    return md5.hexdigest()

def obter_data_hora_atual():
    data_hora_atual = datetime.now()
    return data_hora_atual.strftime('%H:%M:%S.%f')

# %%
data['id'] = data.apply(lambda row: calcular_hash_md5(obter_data_hora_atual()), axis=1)

# %%
data = data[['id', 'checking_status', 'duration', 'credit_history', 'purpose',
       'credit_amount', 'savings_status', 'employment',
       'installment_commitment', 'personal_status', 'other_parties',
       'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
       'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
       'foreign_worker', 'class']]

# %%
data
# Out:
#                                    id checking_status  duration  \
# 0    fa230c7d6cd7a628228f57bebc12f16b              <0       6.0
# 1    e0f782d89aac7433cc922c9d85cf030b        0<=X<200      48.0
# 2    e04997a7a779ccfd76d0c4967ce53dfe     no checking      12.0
# 3    94e72fcafb35fed62cae3ac09d50c483              <0      42.0
# 4    c60f2737502effb8c3bb4b6cd2a5a202              <0      24.0
# ..                                ...             ...       ...
# 995  4913b7ac4a790873efed7691d9838cd0     no checking      12.0
# 996  29ff83c3a455e71c1bdc050f03ba1d52              <0      30.0
# 997  d3d002cdf788e0a39f15b4fd2bca1d44     no checking      12.0
# 998  b5168ca12479348a4ad707b550219920              <0      45.0
# 999  2248239a926f456613d93f335bb1618a        0<=X<200      45.0
#
#                      credit_history              purpose  credit_amount  \
# 0    critical/other existing credit             radio/tv         1169.0
# 1                     existing paid             radio/tv         5951.0
# 2    critical/other existing credit            education         2096.0
# 3                     existing paid  furniture/equipment         7882.0
# 4                delayed previously              new car         4870.0
# ..                              ...                  ...            ...
# 995                   existing paid  furniture/equipment         1736.0
# 996                   existing paid             used car         3857.0
# 997                   existing paid             radio/tv          804.0
# 998                   existing paid             radio/tv         1845.0
# 999  critical/other existing credit             used car         4576.0
#
#        savings_status  employment  installment_commitment     personal_status  \
# 0    no known savings         >=7                     4.0         male single
# 1                <100      1<=X<4                     2.0  female div/dep/mar
# 2                <100      4<=X<7                     2.0         male single
# 3                <100      4<=X<7                     2.0         male single
# 4                <100      1<=X<4                     3.0         male single
# ..                ...         ...                     ...                 ...
# 995              <100      4<=X<7                     3.0  female div/dep/mar
# 996              <100      1<=X<4                     4.0        male div/sep
# 997              <100         >=7                     4.0         male single
# 998              <100      1<=X<4                     4.0         male single
# 999        100<=X<500  unemployed                     3.0         male single
#
#      ... property_magnitude   age other_payment_plans   housing  \
# 0    ...        real estate  67.0                none       own
# 1    ...        real estate  22.0                none       own
# 2    ...        real estate  49.0                none       own
# 3    ...     life insurance  45.0                none  for free
# 4    ...  no known property  53.0                none  for free
# ..   ...                ...   ...                 ...       ...
# 995  ...        real estate  31.0                none       own
# 996  ...     life insurance  40.0                none       own
# 997  ...                car  38.0                none       own
# 998  ...  no known property  23.0                none  for free
# 999  ...                car  27.0                none       own
#
#     existing_credits                        job  num_dependents own_telephone  \
# 0                2.0                    skilled             1.0           yes
# 1                1.0                    skilled             1.0          none
# 2                1.0         unskilled resident             2.0          none
# 3                1.0                    skilled             2.0          none
# 4                2.0                    skilled             2.0          none
# ..               ...                        ...             ...           ...
# 995              1.0         unskilled resident             1.0          none
# 996              1.0  high qualif/self emp/mgmt             1.0           yes
# 997              1.0                    skilled             1.0          none
# 998              1.0                    skilled             1.0           yes
# 999              1.0                    skilled             1.0          none
#
#      foreign_worker class
# 0               yes  good
# 1               yes   bad
# 2               yes  good
# 3               yes  good
# 4               yes   bad
# ..              ...   ...
# 995             yes  good
# 996             yes  good
# 997             yes  good
# 998             yes   bad
# 999             yes  good
#
# [1000 rows x 22 columns]

# %%
train, test = train_test_split(data, shuffle=True, stratify=data['class'])

# %%
train
# Out:
#                                    id checking_status  duration  \
# 774  4487abfbdcf2cd5c247a10bd646681ce           >=200      12.0
# 557  daa785606de7cb4927aa97a6c9e20de1     no checking      21.0
# 73   4a7e1bef15720a38a3015350130186d3        0<=X<200      42.0
# 324  3a9e3f8283ed171509026d6392bf2ad0     no checking      18.0
# 662  ff09b63cd015e4e3892da28912f08d78     no checking      21.0
# ..                                ...             ...       ...
# 954  a231079d1de8fd6e59670303ce5de9e3              <0      12.0
# 742  a3fa93182f7fd8f95ecffae3b6d65d77     no checking      21.0
# 143  589ef69c463d95fed3bac64d6ce0e0f3              <0      18.0
# 649  6dece5424d1885388dbec7f56068fa8f              <0      12.0
# 519  5ace54b037ab381cbb7c3d1535a32212     no checking       6.0
#
#                      credit_history              purpose  credit_amount  \
# 774  critical/other existing credit              new car         1480.0
# 557             no credits/all paid              new car         5003.0
# 73   critical/other existing credit             business         5954.0
# 324  critical/other existing credit              new car         1028.0
# 662                   existing paid  furniture/equipment         2241.0
# ..                              ...                  ...            ...
# 954                   existing paid              new car         1893.0
# 742                   existing paid             radio/tv         3160.0
# 143                   existing paid  furniture/equipment         2462.0
# 649                   existing paid            education          684.0
# 519  critical/other existing credit             radio/tv          700.0
#
#        savings_status  employment  installment_commitment     personal_status  \
# 774       500<=X<1000  unemployed                     2.0         male single
# 557  no known savings      1<=X<4                     1.0  female div/dep/mar
# 73               <100      4<=X<7                     2.0  female div/dep/mar
# 324              <100      1<=X<4                     4.0  female div/dep/mar
# 662              <100         >=7                     4.0         male single
# ..                ...         ...                     ...                 ...
# 954              <100      1<=X<4                     4.0  female div/dep/mar
# 742  no known savings         >=7                     4.0         male single
# 143              <100      1<=X<4                     2.0         male single
# 649              <100      1<=X<4                     4.0         male single
# 519  no known savings         >=7                     4.0         male single
#
#      ... property_magnitude   age other_payment_plans   housing  \
# 774  ...  no known property  66.0                bank  for free
# 557  ...     life insurance  29.0                bank       own
# 73   ...        real estate  41.0                bank       own
# 324  ...        real estate  36.0                none       own
# 662  ...        real estate  50.0                none       own
# ..   ...                ...   ...                 ...       ...
# 954  ...     life insurance  29.0                none       own
# 742  ...     life insurance  41.0                none       own
# 143  ...                car  22.0                none       own
# 649  ...                car  40.0                none      rent
# 519  ...  no known property  36.0                none  for free
#
#     existing_credits                      job  num_dependents own_telephone  \
# 774              3.0  unemp/unskilled non res             1.0          none
# 557              2.0                  skilled             1.0           yes
# 73               2.0       unskilled resident             1.0          none
# 324              2.0                  skilled             1.0          none
# 662              2.0                  skilled             1.0          none
# ..               ...                      ...             ...           ...
# 954              1.0                  skilled             1.0           yes
# 742              1.0                  skilled             1.0           yes
# 143              1.0                  skilled             1.0          none
# 649              1.0       unskilled resident             2.0          none
# 519              2.0                  skilled             1.0          none
#
#      foreign_worker class
# 774             yes  good
# 557             yes   bad
# 73              yes  good
# 324             yes  good
# 662             yes  good
# ..              ...   ...
# 954             yes  good
# 742             yes  good
# 143             yes   bad
# 649             yes   bad
# 519             yes  good
#
# [750 rows x 22 columns]

# %%
cat_cols = X_train.select_dtypes(include=['object']).columns
